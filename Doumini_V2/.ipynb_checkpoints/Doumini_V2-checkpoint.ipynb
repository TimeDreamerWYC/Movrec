# %%
import pandas as pd
movies=pd.read_csv('movies.csv')

# %% [markdown]
# ### 1.数据清洗

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140502 entries, 0 to 140501
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   MOVIE_ID       140502 non-null  int64
#  1   NAME           140502 non-null  object
#  2   ALIAS          30322 non-null   object
#  3   ACTORS         82851 non-null   object
#  4   COVER          50654 non-null   object
#  5   DIRECTORS      70244 non-null   object
#  6   DOUBAN_SCORE   140502 non-null  float64
#  7   DOUBAN_VOTES   140502 non-null  float64
#  8   GENRES         136452 non-null  object
#  9   IMDB_ID        113256 non-null  object
#  10  LANGUAGES      131442 non-null  object
#  11  MINS           140502 non-null  float64
#  12  OFFICIAL_SITE  9821 non-null    object
#  13  REGIONS        136501 non-null  object
#  14  RELEASE_DATE   77687 non-null   object
#  15  SLUG           140502 non-null  object
#  16  STORYLINE      87052 non-null   object
#  17  TAGS           97398 non-null   object
#  18  YEAR           140502 non-null  float64
#  19  ACTOR_IDS      55633 non-null   object
#  20  DIRECTOR_IDS   47231 non-null   object
# dtypes: float64(4), int64(1), object(16)
# memory usage: 22.5+ MB

# %% [markdown]
# 删除无用列并只保留评分大于6.5的电影

# %%
movies = movies.drop(
    columns=['COVER','IMDB_ID','MINS','OFFICIAL_SITE','RELEASE_DATE','SLUG','ACTOR_IDS','DIRECTOR_IDS','LANGUAGES','GENRES','ALIAS']
)
movies = movies[movies['DOUBAN_SCORE'] >= 6.5]

# %%
movies.isnull().sum()
# Out:
# MOVIE_ID           0
# NAME               0
# ACTORS          2023
# DIRECTORS       2688
# DOUBAN_SCORE       0
# DOUBAN_VOTES       0
# REGIONS            0
# STORYLINE        492
# TAGS               0
# YEAR               0
# dtype: int64

# %% [markdown]
# 筛选评分人数大于5000的电影并降序排列

# %%
movies[(movies['DOUBAN_VOTES'] >= 5000)].sort_values(by=['DOUBAN_SCORE','DOUBAN_VOTES'], ascending=[False,False])[['MOVIE_ID','NAME','DOUBAN_SCORE','DOUBAN_VOTES','DIRECTORS','TAGS','REGIONS']].head(50)
# Out:
#        MOVIE_ID                 NAME  DOUBAN_SCORE  DOUBAN_VOTES  \
# 56283   1291546                 霸王别姬           9.6     1167141.0
# 28985  24882562       悲惨世界：25周年纪念演唱会           9.6        6430.0
# 8031   27121232  夏目友人帐 第六季 特别篇 铃响的残株           9.6        5955.0
# 55895   1295124               辛德勒的名单           9.5      637119.0
# 81761  10583098            十二怒汉（电视版）           9.5       12646.0
# 65811   5294851                 控方证人           9.5        7272.0
# 9683   27011740     夏目友人帐 五 特别篇：一夜酒杯           9.5        5629.0
# 80491   1293182                 十二怒汉           9.4      261934.0
# 55698   1307856              背靠背，脸对脸           9.4       38410.0
# 44473   1291831                 灿烂人生           9.4       34451.0
# 65915   1461403                   茶馆           9.4       33529.0
# 16256  26320001       唐顿庄园：2015圣诞特别篇           9.4        8994.0
# 46731   1291561                 千与千寻           9.3     1261985.0
# 78838   1418019                 大闹天宫           9.3      196056.0
# 89012   1293908                 城市之光           9.3       66339.0
# 54487          彼得·霍顿              友情/美国/儿童/成长/美国电影/真情世界/孩子/亲情
# 79056          成濑巳喜男    成濑巳喜男/日本/日本电影/高峰秀子/女性/1960/1960s/仲代达矢
# 20822           须藤友德    空の境界/剧场版/动画/日本/日本动画/动漫/type-moon/空之境界
# 25583          宫本理江子     日剧/小泉今日子/日剧SP/日本/SP/看过的电视剧/中井貴一/内田有紀
# 77327          成濑巳喜男          日本/爱情/成瀬巳喜男/黑白/1964/1960s/经典/剧情
# 12661         涅提·蒂瓦里                  励志/印度/成长/亲情/女权/女性/体育/运动
# 32201  彼特·道格特/鲍勃·彼德森           动画/梦想/美国/冒险/爱情/pixar/温情/Disney
#
#                                                REGIONS
# 56283                                      中国大陆 / 中国香港
# 28985                                               英国
# 8031                                                日本
# 55895                                               美国
# 81761                                               美国
# 65811                                          美国 / 英国
# 9683                                                日本
# 80491                                               美国
# 55698                                      中国大陆 / 中国香港
# 44473                                              意大利
# 65915                                             中国大陆
# 16256                                               英国
# 46731                                               日本
# 78838                                             中国大陆
# 89012                                               美国
# 13879                                               英国
# 17818                                               日本
# 18596                                               日本
# 54312                                      中国香港 / 中国大陆
# 45642                                             中国香港
# 55039                                      中国大陆 / 中国香港
# 71459                                               美国
# 64249                                         意大利 / 美国
# 52478                                               伊朗
# 82241                                               日本
# 52336                                             中国香港
# 85701                                               美国
# 22800                                               英国
# 83614                                             中国大陆
# 39442                                               美国
# 63184                                               日本
# 50782                                               英国
# 45382                                法国 / 德国 / 英国 / 波兰
# 17840                                               英国
# 45821                                               韩国
# 43060                                               日本
# 41960                                         法国 / 比利时
# 53952  南斯拉夫联邦共和国 / 法国 / 德国 / 保加利亚 / 捷克 / 匈牙利 / 英国 / 美国
# 18750                                               日本
# 31521                                               日本
# 61137                                          法国 / 美国
# 82889                                               日本
# 57194                                             中国大陆
# 54487                                               美国
# 79056                                               日本
# 20822                                               日本
# 25583                                               日本
# 77327                                               日本
# 12661                                               印度
# 32201                                               美国

# %% [markdown]
# ### 2.余弦相似度模型构建

# %%
movies['TAGS'] = (
    movies['STORYLINE'].fillna('').astype(str) + " " +
    movies['TAGS'].fillna('').astype(str) + " " +
    movies['YEAR'].fillna('').astype(str)
)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15846 entries, 1378 to 137531
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MOVIE_ID      15846 non-null  int64
#  1   NAME          15846 non-null  object
#  2   ACTORS        13823 non-null  object
#  3   DIRECTORS     13158 non-null  object
#  4   DOUBAN_SCORE  15846 non-null  float64
#  5   DOUBAN_VOTES  15846 non-null  float64
#  6   REGIONS       15846 non-null  object
#  7   STORYLINE     15354 non-null  object
#  8   TAGS          15846 non-null  object
#  9   YEAR          15846 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.3+ MB

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=20000,stop_words='english') #只考虑词频最高的前20000个特征词，自动移除英语停用词（如 "the", "and", "is" 等）

# %%
vector=cv.fit_transform(movies['TAGS'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (15846, 20000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)  #索引有些问题，之后再搞

# %% [markdown]
# ### 后续需添加导演和时代标签等关系网
